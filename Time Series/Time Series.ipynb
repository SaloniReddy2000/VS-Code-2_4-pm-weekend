# %% [markdown]
# # Time Series Analysis

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## Reading CSV files

# %%
import pandas as pd
df=pd.read_csv('AirPassengers.csv')
df
# Out:
#        Month  #Passengers
# 0    1949-01          112
# 1    1949-02          118
# 2    1949-03          132
# 3    1949-04          129
# 4    1949-05          121
# ..       ...          ...
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432
#
# [144 rows x 2 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Month        144 non-null    object
#  1   #Passengers  144 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.4+ KB

# %%
df.columns=['Month','nPass']

# %%
df.head()
# Out:
#      Month  nPass
# 0  1949-01    112
# 1  1949-02    118
# 2  1949-03    132
# 3  1949-04    129
# 4  1949-05    121

# %%
df.isna().sum()
# Out:
# Month    0
# nPass    0
# dtype: int64

# %% [markdown]
# ### If any missing values present apply interpolation

# %%
df['nPass']=df['nPass'].interpolate()

# %%
df.head()
# Out:
#      Month  nPass
# 0  1949-01    112
# 1  1949-02    118
# 2  1949-03    132
# 3  1949-04    129
# 4  1949-05    121

# %% [markdown]
# ### Convert month to datetime

# %%
df['Month']=pd.to_datetime(df['Month'])

# %%
df.head()
# Out:
#        Month  nPass
# 0 1949-01-01    112
# 1 1949-02-01    118
# 2 1949-03-01    132
# 3 1949-04-01    129
# 4 1949-05-01    121

# %%
df.dtypes
# Out:
# Month    datetime64[ns]
# nPass             int64
# dtype: object

# %% [markdown]
# ### Keep row index as month

# %%
df.index=df['Month']

# %%
df.head()
# Out:
#                 Month  nPass
# Month
# 1949-01-01 1949-01-01    112
# 1949-02-01 1949-02-01    118
# 1949-03-01 1949-03-01    132
# 1949-04-01 1949-04-01    129
# 1949-05-01 1949-05-01    121

# %%
df=df.drop(columns=['Month'])

# %%
df.head()
# Out:
#             nPass
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121

# %% [markdown]
# ### Visualize time series data

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(16,8))
plt.plot(df['nPass'])
plt.xlabel('Month')
plt.ylabel('Number of passengers')
plt.title('AirPassengers data')
plt.grid()
plt.show()

# %% [markdown]
# ### Perform time series decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
Q=seasonal_decompose(df['nPass'],model='multiplicative')
Q.plot()

# %% [markdown]
# ## Trend graph with observed details

# %%
plt.figure(figsize=(16,8))
Q.observed.plot()
Q.trend.plot()
plt.xlabel('Month')
plt.ylabel('Number of passengers')
plt.title('Trend analysis for air passengers')
plt.grid()
plt.show()

# %% [markdown]
# ### Seasonality plot

# %%
plt.figure(figsize=(16,8))
Q.seasonal.plot()
plt.xlabel('Month')
plt.ylabel('Number of passengers')
plt.title('Seasonality analysis for air passengers ')
plt.grid()
plt.show()

# %% [markdown]
# ### Residual plot

# %%
plt.figure(figsize=(16,8))
Q.resid.plot()
plt.xlabel('Month')
plt.ylabel('Number of passengers')
plt.title('Residuality analysis for air passengers')
plt.grid()
plt.show()

# %% [markdown]
# ### Time Series Forecasting
# ### Install pmdarima package

# %%
# %pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\vscode\repository\venv\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (1.3.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (3.0.6)
# Requirement already satisfied: numpy>=1.21.2 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (1.26.0)
# Requirement already satisfied: pandas>=0.19 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (2.1.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (1.3.1)
# Requirement already satisfied: scipy>=1.3.2 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (1.11.2)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (2.1.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (65.5.0)
# Requirement already satisfied: packaging>=17.1 in c:\vscode\repository\venv\lib\site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\vscode\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\vscode\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\vscode\repository\venv\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\vscode\repository\venv\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\vscode\repository\venv\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\vscode\repository\venv\lib\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pmdarima.arima import auto_arima

# %%
model=auto_arima(df['nPass'],m=12)

# %%
model.order
# Out:
# (2, 1, 1)

# %%
p=model.order[0]
d=model.order[1]
q=model.order[2]

# %%
p
# Out:
# 2

# %%
d
# Out:
# 1

# %%
q
# Out:
# 1

# %% [markdown]
# ### Forecast data for next 3 years

# %%
forecast,conf_int=model.predict(n_periods=36,return_conf_int=True)

# %%
forecast
# Out:
# 1961-01-01    445.634934
# 1961-02-01    420.395042
# 1961-03-01    449.198378
# 1961-04-01    491.840023
# 1961-05-01    503.394565
# 1961-06-01    566.862550
# 1961-07-01    654.260284
# 1961-08-01    638.597604
# 1961-09-01    540.883864
# 1961-10-01    494.126748
# 1961-11-01    423.332841
# 1961-12-01    465.507712
# 1962-01-01    479.291026
# 1962-02-01    454.177037
# 1962-03-01    483.087203
# 1962-04-01    525.819493
# 1962-05-01    537.450950
# 1962-06-01    600.984197
# 1962-07-01    688.437307
# 1962-08-01    672.821614
# 1962-09-01    575.147743
# 1962-10-01    528.424456
# 1962-11-01    457.659254
# 1962-12-01    499.858481
# 1963-01-01    513.662462
# 1963-02-01    488.566008
# 1963-03-01    517.491053
# 1963-04-01    560.235969
# 1963-05-01    571.878138
# 1963-06-01    635.420475
# 1963-07-01    722.881298
# 1963-08-01    707.272149
# 1963-09-01    609.603831
# 1963-10-01    562.885256
# 1963-11-01    492.124052
# 1963-12-01    534.326671
# Freq: MS, dtype: float64

# %%
forecast=forecast.apply(round)
forecast
# Out:
# 1961-01-01    446
# 1961-02-01    420
# 1961-03-01    449
# 1961-04-01    492
# 1961-05-01    503
# 1961-06-01    567
# 1961-07-01    654
# 1961-08-01    639
# 1961-09-01    541
# 1961-10-01    494
# 1961-11-01    423
# 1961-12-01    466
# 1962-01-01    479
# 1962-02-01    454
# 1962-03-01    483
# 1962-04-01    526
# 1962-05-01    537
# 1962-06-01    601
# 1962-07-01    688
# 1962-08-01    673
# 1962-09-01    575
# 1962-10-01    528
# 1962-11-01    458
# 1962-12-01    500
# 1963-01-01    514
# 1963-02-01    489
# 1963-03-01    517
# 1963-04-01    560
# 1963-05-01    572
# 1963-06-01    635
# 1963-07-01    723
# 1963-08-01    707
# 1963-09-01    610
# 1963-10-01    563
# 1963-11-01    492
# 1963-12-01    534
# Freq: MS, dtype: int64

# %%
conf_int
# Out:
# array([[423.34475094, 467.92511658],
#        [394.23518302, 446.55490116],
#        [419.83140846, 478.56534829],
#        [460.37587373, 523.30417201],
#        [470.37999658, 536.40913406],
#        [532.69880168, 601.02629843],
#        [619.22055901, 689.30000963],
#        [602.87921604, 674.31599104],
#        [504.63055231, 577.13717502],
#        [457.44514984, 530.80834643],
#        [386.3030106 , 460.36267117],
#        [428.19044593, 502.82497842],
#        [433.49653884, 525.08551376],
#        [405.10774907, 503.24632483],
#        [431.15437638, 535.02002912],
#        [471.83916844, 579.79981805],
#        [481.87209035, 593.02980929],
#        [544.15500525, 657.81338881],
#        [630.60709073, 746.26752372],
#        [614.17741433, 731.46581272],
#        [515.83056926, 634.46491613],
#        [468.54219966, 588.30671331],
#        [397.2952923 , 518.02321528],
#        [439.07790127, 560.63906114],
#        [446.32509131, 580.99983223],
#        [418.31603539, 558.81598086],
#        [444.62194643, 590.36015987],
#        [485.39943994, 635.07249774],
#        [495.4479624 , 648.30831366],
#        [557.69634351, 713.1446065 ],
#        [644.08397085, 801.67862509],
#        [627.57137805, 786.97291922],
#        [529.13050031, 690.07716124],
#        [481.74160891, 644.02890374],
#        [410.39065083, 573.85745237],
#        [452.0675645 , 616.58577818]])

# %% [markdown]
# ### Get lower and upper confidence bound

# %%
lower=conf_int[:,0]
upper=conf_int[:,1]

# %%
lower
# Out:
# array([423.34475094, 394.23518302, 419.83140846, 460.37587373,
#        470.37999658, 532.69880168, 619.22055901, 602.87921604,
#        504.63055231, 457.44514984, 386.3030106 , 428.19044593,
#        433.49653884, 405.10774907, 431.15437638, 471.83916844,
#        481.87209035, 544.15500525, 630.60709073, 614.17741433,
#        515.83056926, 468.54219966, 397.2952923 , 439.07790127,
#        446.32509131, 418.31603539, 444.62194643, 485.39943994,
#        495.4479624 , 557.69634351, 644.08397085, 627.57137805,
#        529.13050031, 481.74160891, 410.39065083, 452.0675645 ])

# %%
upper
# Out:
# array([467.92511658, 446.55490116, 478.56534829, 523.30417201,
#        536.40913406, 601.02629843, 689.30000963, 674.31599104,
#        577.13717502, 530.80834643, 460.36267117, 502.82497842,
#        525.08551376, 503.24632483, 535.02002912, 579.79981805,
#        593.02980929, 657.81338881, 746.26752372, 731.46581272,
#        634.46491613, 588.30671331, 518.02321528, 560.63906114,
#        580.99983223, 558.81598086, 590.36015987, 635.07249774,
#        648.30831366, 713.1446065 , 801.67862509, 786.97291922,
#        690.07716124, 644.02890374, 573.85745237, 616.58577818])

# %%
lower=pd.Series(lower)
lower.index=forecast.index
lower=lower.apply(round)
lower
# Out:
# 1961-01-01    423
# 1961-02-01    394
# 1961-03-01    420
# 1961-04-01    460
# 1961-05-01    470
# 1961-06-01    533
# 1961-07-01    619
# 1961-08-01    603
# 1961-09-01    505
# 1961-10-01    457
# 1961-11-01    386
# 1961-12-01    428
# 1962-01-01    433
# 1962-02-01    405
# 1962-03-01    431
# 1962-04-01    472
# 1962-05-01    482
# 1962-06-01    544
# 1962-07-01    631
# 1962-08-01    614
# 1962-09-01    516
# 1962-10-01    469
# 1962-11-01    397
# 1962-12-01    439
# 1963-01-01    446
# 1963-02-01    418
# 1963-03-01    445
# 1963-04-01    485
# 1963-05-01    495
# 1963-06-01    558
# 1963-07-01    644
# 1963-08-01    628
# 1963-09-01    529
# 1963-10-01    482
# 1963-11-01    410
# 1963-12-01    452
# Freq: MS, dtype: int64

# %%
upper=pd.Series(upper)
upper.index=forecast.index
upper=upper.apply(round)
upper
# Out:
# 1961-01-01    468
# 1961-02-01    447
# 1961-03-01    479
# 1961-04-01    523
# 1961-05-01    536
# 1961-06-01    601
# 1961-07-01    689
# 1961-08-01    674
# 1961-09-01    577
# 1961-10-01    531
# 1961-11-01    460
# 1961-12-01    503
# 1962-01-01    525
# 1962-02-01    503
# 1962-03-01    535
# 1962-04-01    580
# 1962-05-01    593
# 1962-06-01    658
# 1962-07-01    746
# 1962-08-01    731
# 1962-09-01    634
# 1962-10-01    588
# 1962-11-01    518
# 1962-12-01    561
# 1963-01-01    581
# 1963-02-01    559
# 1963-03-01    590
# 1963-04-01    635
# 1963-05-01    648
# 1963-06-01    713
# 1963-07-01    802
# 1963-08-01    787
# 1963-09-01    690
# 1963-10-01    644
# 1963-11-01    574
# 1963-12-01    617
# Freq: MS, dtype: int64

# %% [markdown]
# ### Plotting forecast sheet

# %%
plt.figure(figsize=(16,8))
plt.plot(df['nPass'],label='Original')
plt.plot(forecast,label='Forecast')
plt.fill_between(forecast.index,lower,upper,color='gray',alpha=0.6,label='Confidence Interval')
plt.xlabel('Month')
plt.ylabel('Number of passengers')
plt.title('Forecast Sheet')
plt.grid()
plt.legend(loc='upper center')
plt.show()

# %% [markdown]
# ### Save above in forecast dataframe

# %%
df_forecast=forecast.to_frame()
df_forecast.columns=['Forecast']
df_forecast
# Out:
#             Forecast
# 1961-01-01       446
# 1961-02-01       420
# 1961-03-01       449
# 1961-04-01       492
# 1961-05-01       503
# 1961-06-01       567
# 1961-07-01       654
# 1961-08-01       639
# 1961-09-01       541
# 1961-10-01       494
# 1961-11-01       423
# 1961-12-01       466
# 1962-01-01       479
# 1962-02-01       454
# 1962-03-01       483
# 1962-04-01       526
# 1962-05-01       537
# 1962-06-01       601
# 1962-07-01       688
# 1962-08-01       673
# 1962-09-01       575
# 1962-10-01       528
# 1962-11-01       458
# 1962-12-01       500
# 1963-01-01       514
# 1963-02-01       489
# 1963-03-01       517
# 1963-04-01       560
# 1963-05-01       572
# 1963-06-01       635
# 1963-07-01       723
# 1963-08-01       707
# 1963-09-01       610
# 1963-10-01       563
# 1963-11-01       492
# 1963-12-01       534

# %%
df_forecast['Lower']=lower
df_forecast['Upper']=upper

# %%
df_forecast
# Out:
#             Forecast  Lower  Upper
# 1961-01-01       446    423    468
# 1961-02-01       420    394    447
# 1961-03-01       449    420    479
# 1961-04-01       492    460    523
# 1961-05-01       503    470    536
# 1961-06-01       567    533    601
# 1961-07-01       654    619    689
# 1961-08-01       639    603    674
# 1961-09-01       541    505    577
# 1961-10-01       494    457    531
# 1961-11-01       423    386    460
# 1961-12-01       466    428    503
# 1962-01-01       479    433    525
# 1962-02-01       454    405    503
# 1962-03-01       483    431    535
# 1962-04-01       526    472    580
# 1962-05-01       537    482    593
# 1962-06-01       601    544    658
# 1962-07-01       688    631    746
# 1962-08-01       673    614    731
# 1962-09-01       575    516    634
# 1962-10-01       528    469    588
# 1962-11-01       458    397    518
# 1962-12-01       500    439    561
# 1963-01-01       514    446    581
# 1963-02-01       489    418    559
# 1963-03-01       517    445    590
# 1963-04-01       560    485    635
# 1963-05-01       572    495    648
# 1963-06-01       635    558    713
# 1963-07-01       723    644    802
# 1963-08-01       707    628    787
# 1963-09-01       610    529    690
# 1963-10-01       563    482    644
# 1963-11-01       492    410    574
# 1963-12-01       534    452    617

# %%
df_forecast.to_csv('forecast.csv')
